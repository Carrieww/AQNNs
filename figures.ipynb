# %% [markdown]
# # Relative Error

# %%
# non-PQA AVG
import matplotlib.pyplot as plt
import numpy as np

# Example accuracy lists for different datasets
eICU = [3.20805751, 3.452021234, 15.86978541, 25.68311078, 25.38736342]
mimic = [4.522750354, 3.256023604, 6.241038529, 8.871778397, 8.898703253]
amazon_hh = [12.51566459, 15.14134634, 46.75772289, 58.79071471, 58.04343469]
amazon_e = [12.38261998, 14.09972436, 52.86658329, 55.82805243, 55.5806142]
jackson = [2.535128728, 3.501995336, 15.94934642, 23.76080093, 24.05277482]
methods = ['SPRinT-V', 'PQE-PT','PQE-RT','SUPG-PT', 'SUPG-RT']

# Hatching patterns for each dataset
hatches = ['XX', '*', '||', '--', '..']

data = [eICU, mimic, amazon_e, amazon_hh, jackson]
datasets = [r'$\mathbf{eICU}$', r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 4))
bar_width = 0.15  # Reduced bar width for more spacing
spacing = 0.03  # Extra spacing between groups
x = np.arange(len(methods))

# Plot bars for each dataset with hatching patterns
for i, (acc, hatch, label) in enumerate(zip(data, hatches, datasets)):
    ax.bar(
        x + i * (bar_width + spacing),
        acc,
        bar_width,
        color='white',  # All bars are white to highlight hatching
        edgecolor='black',  # Black border for better visibility
        hatch=hatch,
        label=label
    )

# Customize the plot
ax.set_ylabel('RE', fontsize=24, fontweight='bold')
ax.set_xticks(x + (bar_width + spacing) * (len(data) - 1) / 2)
ax.set_xticklabels(methods, fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=18, rotation=45)
ax.tick_params(axis='x', labelsize=18)

# Add legend
ax.legend(fontsize=18, loc='best')

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/RE/RE_PQE_AVG.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# nonPQA VAR
import matplotlib.pyplot as plt
import numpy as np

# Example accuracy lists for different datasets
eICU = [8.514767899, 9.747483821, 13.74532472, 25.17056646, 25.03248177]
mimic = [5.262191654, 8.208648115, 5.463872557, 13.07034185, 5.538319973]
amazon_hh = [16.31842652, 15.56922919, 47.98850949, 64.94100608, 63.21412619]
amazon_e = [17.34830491, 17.56654696, 62.28210079, 71.97447653, 69.23137088]
jackson = [4.964002626, 5.20320386, 9.09462183, 22.95265603, 23.04091495]
methods = ['SPRinT-V', 'PQE-PT','PQE-RT','SUPG-PT', 'SUPG-RT']

# Hatching patterns for each dataset
hatches = ['XX', '*', '||', '--', '..']

data = [eICU, mimic, amazon_e, amazon_hh, jackson]
datasets = [r'$\mathbf{eICU}$', r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 4))
bar_width = 0.15  # Bar width
spacing = 0.03  # Extra spacing between groups
x = np.arange(len(methods))

# Plot bars for each dataset with hatching patterns
for i, (acc, hatch, label) in enumerate(zip(data, hatches, datasets)):
    bars = ax.bar(
        x + i * (bar_width + spacing),
        acc,
        bar_width,
        color='white',  # All bars are white to highlight hatching
        edgecolor='black',  # Black border for better visibility
        hatch=hatch,
        label=label
    )

# Customize the plot
ax.set_ylabel('RE', fontsize=24, fontweight='bold')
ax.set_xticks(x + (bar_width + spacing) * (len(data) - 1) / 2)
ax.set_xticklabels(methods, fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=18, rotation=45)
ax.tick_params(axis='x', labelsize=18)

# Add legend
ax.legend(fontsize=18, loc='best')

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/RE/RE_PQE_VAR.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# non-PQA SUM
plt.show()
import matplotlib.pyplot as plt
import numpy as np

# Example accuracy lists for different datasets
eICU = [6.431435425, 19.53085459, 350.6235419, 19.29534547, 595.3612194]
mimic = [23.88718187, 43.58919274, 28.91384113, 75.06393722, 54.8287894]
amazon_hh = [34.42899632, 49.78436754, 4854.96442, 49.91342159, 14743.84687]
amazon_e = [32.55900035, 41.88763726, 7059.887331, 42.69006641, 16631.63557]
jackson = [6.191333019, 9.19866845, 114.4351911, 12.16915502, 291.6950167]
methods = ['SPRinT-V', 'PQE-PT','PQE-RT','SUPG-PT', 'SUPG-RT']

# Hatching patterns for each dataset
hatches = ['XX', '*', '||', '--', '..']

data = [eICU, mimic, amazon_e, amazon_hh, jackson]
datasets = [r'$\mathbf{eICU}$', r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 4))
bar_width = 0.15  # Reduced bar width for more spacing
spacing = 0.03  # Extra spacing between groups
x = np.arange(len(methods))

# Plot bars for each dataset with hatching patterns
for i, (acc, hatch, label) in enumerate(zip(data, hatches, datasets)):
    ax.bar(
        x + i * (bar_width + spacing),
        acc,
        bar_width,
        color='white',  # All bars are white to highlight hatching
        edgecolor='black',  # Black border for better visibility
        hatch=hatch,
        label=label
    )

# Customize the plot
ax.set_ylabel('RE', fontsize=24, fontweight='bold')
ax.set_xticks(x + (bar_width + spacing) * (len(data) - 1) / 2)
ax.set_xticklabels(methods, fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=18, rotation=45)
ax.tick_params(axis='x', labelsize=18)

# Add legend
ax.legend(fontsize=18, loc='best')

# Set y-limit to enhance visibility of smaller values
plt.ylim(0, 200)

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/RE/RE_PQE_SUM.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# non-PQA PERCENT
import matplotlib.pyplot as plt
import numpy as np

# Example accuracy lists for different datasets
eICU = [5.956130705, 19.48157737, 253.2438187, 22.11833538, 428.711036]
mimic = [6.206882739, 42.70987898, 40.99515449, 72.35275617, 75.14416654]
amazon_hh = [23.54273557, 33.22890675, 3075.636116, 16.35921863, 9017.564302]
amazon_e = [23.66527655, 29.53449953, 4538.613844, 19.72349559, 10985.46197]
jackson = [4.062129847, 5.983461839, 84.945804, 28.68029947, 215.4363616]
methods = ['SPRinT-C', 'PQE-PT','PQE-RT','SUPG-PT', 'SUPG-RT']

# Hatching patterns for each dataset
hatches = ['XX', '*', '||', '--', '..']

data = [eICU, mimic, amazon_e, amazon_hh, jackson]
datasets = [r'$\mathbf{eICU}$', r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 4))
bar_width = 0.15  # Reduced bar width for more spacing
spacing = 0.03  # Extra spacing between groups
x = np.arange(len(methods))

# Plot bars for each dataset with hatching patterns
for i, (acc, hatch, label) in enumerate(zip(data, hatches, datasets)):
    ax.bar(
        x + i * (bar_width + spacing),
        acc,
        bar_width,
        color='white',  # All bars are white to highlight hatching
        edgecolor='black',  # Black border for better visibility
        hatch=hatch,
        label=label
    )

# Customize the plot
ax.set_ylabel('RE', fontsize=24, fontweight='bold')
ax.set_xticks(x + (bar_width + spacing) * (len(data) - 1) / 2)
ax.set_xticklabels(methods, fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=18, rotation=45)
ax.tick_params(axis='x', labelsize=18)

# Add legend
ax.legend(fontsize=18, loc='best')

# Set y-limit to enhance visibility of smaller values
plt.ylim(0, 200)

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/RE/RE_PQE_PERCENT.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # F1 score performance

# %%
# # PQA AVG
# import matplotlib.pyplot as plt
# import numpy as np
# 
# # Example accuracy lists for different datasets
# eICU = [0.84315, 0.67413, 0.40653,0.36968]#,0]
# mimic = [0.85715, 0.79341, 0.76187, 0.70117]#,0]
# amazon_hh = [0.6925, 0.44181, 0.18331, 0.18096]#,0]
# amazon_e = [0.53044, 0.19069, 0.18194, 0.17669]#,0]
# jackson = [0.93511, 0.86686, 0.77071, 0.67622]#,0]
# methods = ['SPRinT','ProxyOnly','PQE-RT', 'SUPG']# , 'TopK']
# 
# # Bar colors for each dataset
# colors = ['#073E7E', '#C25759', '#36600e', '#fac45a', '#7f7f7f']
# 
# data = [eICU, mimic, amazon_e, amazon_hh,jackson]
# datasets = [r'$\mathbf{eICU}$',r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']
# 
# # Create the plot
# fig, ax = plt.subplots(figsize=(6, 4))
# bar_width = 0.15  # Reduced bar width for more spacing
# spacing = 0.03  # Extra spacing between groups
# x = np.arange(len(methods))
# 
# # Plot bars for each dataset
# for i, (acc, color, label) in enumerate(zip(data, colors, datasets)):
#     ax.bar(x + i * (bar_width + spacing), acc, bar_width, color=color, label=label)
# 
# # Customize the plot
# ax.set_ylabel('F1 Score', fontsize=24, fontweight='bold')
# ax.set_xticks(x + (bar_width + spacing) * 1.5)
# ax.set_xticklabels(methods, fontsize=18, fontweight='bold')
# ax.tick_params(axis='y', labelsize=18,rotation=45)
# ax.tick_params(axis='x', labelsize=12)
# 
# # Add legend
# # ax.legend(fontsize=18, loc='best')
# # plt.title('PQA AVG', fontsize=18, fontweight='bold')
# # plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/RE_PQA_AVG.png', dpi=300, bbox_inches='tight')
# 
# plt.show()

# %% [markdown]
# # F1 score curve

# %%
# Using pandas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("/Users/wangyun/Desktop/Graph_HT_2/Dujian/AQUAPRO-main/results/SPRinT_PQE/avg_icd9_eICU_test0212_fbeta_score.csv")

l = df['F1 score'].tolist()
x = np.arange(0.0001, 1.0, 0.01)
color="black"

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))

# Set x-axis label
ax1.set_xlabel(r'$\mathbf{t}$', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([0,0.2,0.4,0.6,0.8,1])
ax1.set_xticklabels([0,0.2,0.4,0.6,0.8,1], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$\mathbf{F}\mathbf{\beta}_S$', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, l, marker='o', linewidth=3, markersize=12)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)

# plt.axvline(x=0.7204, color='black', linestyle='--', label=r"$\mathbf{t}^*$", linewidth=3)
# ax1.legend(fontsize=18, loc='best')

plt.ylim(0.1, 1)
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/fbetaScore/fbeta_fig_eICU_ori.png', dpi=300, bbox_inches='tight')
plt.show()
# print(df)

# %%
# Using pandas
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/wangyun/Desktop/Graph_HT_2/Dujian/AQUAPRO-main/results/SPRinT_PQE/avg_night-street_test0212_fbeta_score.csv")

l = df['F1 score'].tolist()

x = np.arange(0.0001, 1.0, 0.01)
color="black"

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))

# Set x-axis label
ax1.set_xlabel(r'$\mathbf{t}$', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([0,0.2,0.4,0.6,0.8,1])
ax1.set_xticklabels([0,0.2,0.4,0.6,0.8,1], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$\mathbf{F}\mathbf{\beta}_S$', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, l, marker='o', linewidth=3, markersize=12)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)

# plt.axvline(x=0.9641, color='black', linestyle='--', label=r"$\mathbf{t}^*$", linewidth=3)
# ax1.legend(fontsize=18, loc='best')

plt.ylim(0.4, 1)
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/fbetaScore/fbeta_fig_Jackson_ori.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # sample complexity

# %%
# eICU, AVG, s = 500-3000, PQE
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (sample size increments)
x = list(range(500, 8001, 500))

# Y-axis values (percent difference between prop_D and prop_S)
y = np.array([31.3368,
31.3198,
31.3222,
31.3202,
31.3209,
31.3232,
31.3152,
31.3198,
31.3152,
31.3144,
31.3121,
31.3107,
31.3077,
31.3031,
31.303,
31.3047])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'black'

# Set x-axis label
ax1.set_xlabel(r'Sample Size', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([2000,4000,6000,8000])
ax1.set_xticklabels([2000,4000,6000,8000], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$\mathbf{AVG}_\mathbf{S}$', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, y, marker='o', color=color, linewidth=3, markersize=14)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)
plt.axhline(y=31.3024, color=color, linestyle='--',linewidth=3,label = r'$\mathbf{AVG}_\mathbf{D}$')
ax1.legend(fontsize=18, loc='best')
plt.ylim(31.2,31.4)
# Ensure the plotting box size is consistent with Plot 1
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/sample_complexity/avg_eICU_s.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# eICU, PCT, s = 500-3000, PQE
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (sample size increments)
x = list(range(500, 8001, 500))

# Y-axis values (percent difference between prop_D and prop_S)
y = np.array([0.0748,
0.0723,
0.0722,
0.0717,
0.0718,
0.0719,
0.0717,
0.072,
0.0717,
0.0719,
0.072,
0.072,
0.072,
0.072,
0.072,
0.0719])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'black'

# Set x-axis label
ax1.set_xlabel(r'Sample Size', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([2000,4000,6000,8000])
ax1.set_xticklabels([2000,4000,6000,8000], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$\mathbf{PCT}_\mathbf{S}$', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, y, marker='o', color=color, linewidth=3, markersize=14)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)
plt.axhline(y=0.0719, color=color, linestyle='--',linewidth=3,label = r'$\mathbf{PCT}_\mathbf{D}$')
ax1.legend(fontsize=18, loc='best')
plt.ylim(0.07, 0.08)
# Ensure the plotting box size is consistent with Plot 1
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/sample_complexity/pct_eICU_s.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# eICU, AVG, s_p = 50 - 500, PQE
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (sample size increments)
x = list(range(100, 901, 50))

# Y-axis values (percent difference between prop_D and prop_S)
y = np.array([2.721108139,
2.757515179,
2.690497614,
2.70913486,
2.828025264,
2.968891252,
2.903452421,
2.875574502,
2.756246473,
2.716882829,
2.72688842,
2.791128857,
2.619148815,
2.575786411,
2.483699707,
2.510448697,
2.469887137])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'black'

# Set x-axis label
ax1.set_xlabel(r'Pilot Sample Size', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([200,400,600,800])
ax1.set_xticklabels([200,400,600,800], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$\mathbf{RE}$', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, y, marker='o', color=color, linewidth=3, markersize=14)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)
# plt.axhline(y=0.0719, color=color, linestyle='--',linewidth=3,label = r'$\mathbf{AVG}_\mathbf{D}$')
# ax1.legend(fontsize=18, loc='best')
# plt.ylim(31.3,31.4)
# Ensure the plotting box size is consistent with Plot 1
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/sample_complexity/avg_eICU_s_p_re.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# eICU, AVG, s_p = 50 - 500, PQE
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (sample size increments)
x = list(range(100, 901, 50))

# Y-axis values (percent difference between prop_D and prop_S)
y = np.array([0.944015361,
0.952863215,
0.956422444,
0.962465669,
0.965012027,
0.967542082,
0.970949149,
0.974133391,
0.97671625,
0.97994997,
0.982460952,
0.985574633,
0.987050907,
0.988677325,
0.99105149,
0.992948613,
0.995891456])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'black'

# Set x-axis label
ax1.set_xlabel(r'Pilot Sample Size', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([200,400,600,800])
ax1.set_xticklabels([200,400,600,800], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$\mathbf{F}\mathbf{\beta}_S$', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, y, marker='o', color=color, linewidth=3, markersize=14)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)
# plt.axhline(y=0.0719, color=color, linestyle='--',linewidth=3,label = r'$\mathbf{AVG}_\mathbf{D}$')
# ax1.legend(fontsize=18, loc='best')
# plt.ylim(0.88,1)
# Ensure the plotting box size is consistent with Plot 1
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/sample_complexity/avg_eICU_s_p_fbeta.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# eICU, PCT, s_p = 50 - 500, PQE
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (sample size increments)
x = list(range(100, 901, 50))

# Y-axis values (percent difference between prop_D and prop_S)
y = np.array([10.50096658,
9.610912376,
7.312466125,
6.395880759,
6.571210479,
5.824480578,
5.69701897,
5.983947606,
5.707687444,
5.566820235,
5.186892502,
5.046025294,
5.181418248,
5.277154472,
5.425953026,
5.351553749,
5.574751581])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'black'

# Set x-axis label
ax1.set_xlabel(r'Pilot Sample Size', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([200,400,600,800])
ax1.set_xticklabels([200,400,600,800], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$\mathbf{RE}$', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, y, marker='o', color=color, linewidth=3, markersize=14)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)
# plt.axhline(y=0.0719, color=color, linestyle='--',linewidth=3,label = r'$\mathbf{AVG}_\mathbf{D}$')
# ax1.legend(fontsize=18, loc='best')
# plt.ylim(31.3,31.4)
# Ensure the plotting box size is consistent with Plot 1
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/sample_complexity/pct_eICU_s_p_re.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# eICU, AVG, s_p = 50 - 500, PQE
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (sample size increments)
x = list(range(100, 901, 50))

# Y-axis values (percent difference between prop_D and prop_S)
y = np.array([29.48584909,
28.26225092,
22.80631833,
9.267685941,
4.193780381,
3.563681295,
7.569279605,
6.644767992,
7.752784423,
5.415341444,
2.864465837,
1.605589235,
0.654400448,
0.483571295,
1.900187487,
0.818298382,
0.287063855])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color = 'black'

# Set x-axis label
ax1.set_xlabel(r'Pilot Sample Size', fontsize=24, fontweight="bold")

# Set custom x-axis ticks
ax1.set_xticks([200,400,600,800])
ax1.set_xticklabels([200,400,600,800], fontsize=18)

# Set y-axis label and plot
ax1.set_ylabel(r'$|\mathbf{P}_S - \mathbf{R}_S|$ (1e-3)', color=color, fontsize=24, fontweight="bold")

ax1.plot(x, y, marker='o', color=color, linewidth=3, markersize=14)

# Set tick parameters
ax1.tick_params(axis='x', labelcolor=color, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color, labelsize=18,rotation=45)
# plt.axhline(y=0.0719, color=color, linestyle='--',linewidth=3,label = r'$\mathbf{AVG}_\mathbf{D}$')
# ax1.legend(fontsize=18, loc='best')
# plt.ylim(31.3,31.4)
# Ensure the plotting box size is consistent with Plot 1
fig.tight_layout()

# Save to file with consistent layout
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/sample_complexity/pct_eICU_s_p_pr.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # level of difficulty

# %%
# AVG, F1, eICU
import matplotlib.pyplot as plt
import numpy as np

radius = [0.9,0.85,0.8,0.75,0.7,0.65,0.6,0.55,0.5,0.45,0.4]
percent_NN = np.array([17.92132103,
17.92132103,
17.10781933,
14.5701797,
10.12627489,
8.195726081,
5.803788247,
2.986886838,
0.728508985,
0.728508985,
0.728508985])

F1_score = np.array([0.982460952,
0.982528284,
0.969838824,
0.946390294,
0.923193696,
0.901929934,
0.889410877,
0.904518761,
0.873356639,
0.881102201,
0.883137267])
fig, ax1 = plt.subplots(figsize=(8, 4))

# ax1
color_line = 'black'
line = ax1.plot(radius, F1_score, color=color_line, marker='o', linewidth=3, label='F1 Score',markersize=14)
ax1.set_ylabel(r'$\mathbf{F}\mathbf{\beta}_S$', fontsize=24, color=color_line, fontweight='bold')
ax1.tick_params(axis='y', labelsize=18, labelcolor=color_line,rotation=45)
ax1.spines['left'].set_color(color_line)  


ax2 = ax1.twinx()
color_bar = 'black'#'#1f77b4'
bars = ax2.bar(radius, percent_NN, color=color_bar, alpha=0.3, width=0.05, label='Percent NN (%)')
ax2.set_ylabel( r'$\rho$', fontsize=24, color=color_bar, fontweight='bold')
ax2.tick_params(axis='y', labelsize=18, labelcolor=color_bar,rotation=45)
ax2.spines['right'].set_color(color_bar)  


ax1.set_xlabel('Radius $r$', fontsize=24, fontweight='bold')
ax1.tick_params(axis='x', labelsize=18)

lines = [line[0], bars]
labels = [r'$\mathbf{F1}_S$', r'$\rho$']
# ax1.legend(lines, labels, loc='upper left', fontsize=14)

fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/level_of_difficulty/avg_eICU_fbeta.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# AVG eICU
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [0.9,0.85,0.8,0.75,0.7,0.65,0.6,0.55,0.5,0.45,0.4]
# relative error
RE = np.array([2.72688842,
2.763807214,
2.301380955,
4.1372254,
3.166669526,
4.319504603,
4.736303826,
9.790680071,
15.2003319,
17.67174994,
15.21605049])
# absolute error
AE = np.array([1.262497609,
1.27959031,
1.079460369,
1.945530244,
1.50910408,
2.046357307,
2.26450811,
4.570576014,
7.362027417,
8.559017557,
7.369640452])   
# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel('Radius $r$', fontsize=24, fontweight="bold")
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE, marker='o', color=color1, linewidth=3, markersize=14, label='RE')
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(0, 20)  # Set Y-axis range for Relative Error

# Create secondary y-axis
# ax2 = ax1.twinx()
# color2 = 'black'
# ax2.set_ylabel('AE', color=color2, fontsize=24, fontweight="bold")
# ax2.plot(radius, AE, marker='X', color=color2, linewidth=3, markersize=12, linestyle='--',label='AE')
# ax2.tick_params(axis='y', labelcolor=color2, labelsize=18, rotation=45)
# ax2.set_ylim(0, 10)  # Set Y-axis range for Absolute Error

# Adjust layout and save
# lines = [line[0], bars]
# labels = [r'$\mathbf{Relative}$ $\mathbf{Error}$', r'$\rho$']
# ax1.legend(lines, labels, loc='lower right', fontsize=14)
# ax1.legend(fontsize=18, loc='upper left')
# ax2.legend(fontsize=18, loc='upper right')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/level_of_difficulty/avg_eICU_re.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# PCT, PR, eICU
import matplotlib.pyplot as plt
import numpy as np

radius = [0.9,0.85,0.8,0.75,0.7,0.65,0.6,0.55,0.5,0.45,0.4]
percent_NN = np.array([17.92132103,
17.92132103,
17.10781933,
14.5701797,
10.12627489,
8.195726081,
5.803788247,
2.986886838,
0.728508985,
0.728508985,
0.728508985])

pr_balance = np.array([2.864465837,
2.885550556,
5.258044256,
1.612573369,
4.7945277,
3.812191334,
16.74093481,
15.44286985,
124.2111592,
20.13708514,
309.9603175])   

fig, ax1 = plt.subplots(figsize=(8, 4))

# ax1
color_line = 'black'
line = ax1.plot(radius, pr_balance, color=color_line, marker='o', linewidth=3, label='F1 Score', markersize=14)
ax1.set_ylabel(r'$|\mathbf{P}_S - \mathbf{R}_S|$ (1e-3)', fontsize=24, color=color_line, fontweight='bold')
ax1.tick_params(axis='y', labelsize=18, labelcolor=color_line,rotation=45)
ax1.spines['left'].set_color(color_line)  
# ax1.set_ylim(0, 16)

ax2 = ax1.twinx()
color_bar = 'black' #'#1f77b4'
bars = ax2.bar(radius, percent_NN, color=color_bar, alpha=0.3, width=0.05, label='Percent NN (%)')
ax2.set_ylabel( r'$\rho$', fontsize=24, color=color_bar, fontweight='bold')
ax2.tick_params(axis='y', labelsize=18, labelcolor=color_bar,rotation=45)
ax2.spines['right'].set_color(color_bar)  


ax1.set_xlabel('Radius $r$', fontsize=24, fontweight='bold')
ax1.tick_params(axis='x', labelsize=18)

# lines = [line[0], bars]
# labels = [r'$|\text{P}_S-\text{R}_S| (1e-3)$', r'$\rho$']
# ax1.legend(lines, labels, loc='upper left', fontsize=14)

fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/level_of_difficulty/pct_eICU_pr.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# PCT eICU
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [0.9,0.85,0.8,0.75,0.7,0.65,0.6,0.55,0.5,0.45,0.4]
# relative error
RE = np.array([5.186892502,
5.149692864,
5.017799858,
6.616088889,
8.986522782,
9.388187654,
13.09924686,
13.78520325,
26.53822222,
30.32711111,
49.93377778])
# absolute error
AE = np.array([9.295596568,
9.228929901,
8.58436134,
9.639760401,
9.1,
7.694301441,
7.602525498,
4.117484216,
1.933333333,
2.209357293,
3.637720576])   
# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel('Radius $r$', fontsize=24, fontweight="bold")
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE, marker='o', color=color1, linewidth=3, markersize=14, label='RE')
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
# ax1.set_ylim(0, 40)  # Set Y-axis range for Relative Error

# Create secondary y-axis
# ax2 = ax1.twinx()
# color2 = 'black'
# ax2.set_ylabel('AE (1e-3)', color=color2, fontsize=24, fontweight="bold")
# ax2.plot(radius, AE, marker='X', color=color2, linewidth=3, markersize=12, linestyle='--',label='AE')
# ax2.tick_params(axis='y', labelcolor=color2, labelsize=18, rotation=45)
# ax2.set_ylim(0, 12)  # Set Y-axis range for Absolute Error

# Adjust layout and save
# ax1.legend(fontsize=18, loc='lower left')
# ax2.legend(fontsize=18, loc='upper right')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/level_of_difficulty/pct_eICU_re.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Execution Time

# %%
# # execution time for AVG PQE for all datasets
# import matplotlib.pyplot as plt
# import numpy as np
# 
# # Example accuracy lists for different datasets
# eICU = [30.07706667, 0, 0.158366667, 0.026466667]
# mimic = [7.7769, 0, 0.0821, 0.0209]
# amazon_hh = [30.98746667, 0, 0.1028, 0.0169]
# amazon_e = [0,0,0,0]
# jackson = [27.9371, 0, 0.171, 0.02]
# methods = ['SPRinT','ProxyOnly','PQE-RT', 'SUPG']# , 'TopK']
# 
# # Bar colors for each dataset
# colors = ['#073E7E', '#C25759', '#36600e', '#fac45a', '#7f7f7f']
# 
# data = [eICU, mimic, amazon_e, amazon_hh,jackson]
# datasets = [r'$\mathbf{eICU}$',r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']
# 
# # Create the plot
# fig, ax = plt.subplots(figsize=(6, 4))
# bar_width = 0.15  # Reduced bar width for more spacing
# spacing = 0.03  # Extra spacing between groups
# x = np.arange(len(methods))
# 
# # Plot bars for each dataset
# for i, (acc, color, label) in enumerate(zip(data, colors, datasets)):
#     ax.bar(x + i * (bar_width + spacing), acc, bar_width, color=color, label=label)
# 
# # Customize the plot
# ax.set_ylabel('Time', fontsize=24, fontweight='bold')
# ax.set_xticks(x + (bar_width + spacing) * 1.5)
# ax.set_xticklabels(methods, fontsize=14, fontweight='bold')
# ax.tick_params(axis='y', labelsize=18,rotation=45)
# ax.tick_params(axis='x', labelsize=14)
# 
# # Add legend
# # ax.legend(fontsize=14, loc='best')
# # plt.title('PQA PERCENT', fontsize=18, fontweight='bold')
# fig.tight_layout()
# plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/RE/RE_PQA_PERCENT.png', dpi=300, bbox_inches='tight')
# 
# plt.show()

# %% [markdown]
# # scalability

# %%
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
x = [2500, 5000, 7500, 10000]  

# relative error
y1 = np.array([2.407313016,
3.659689457,
2.186668035,
2.852060541])
# absolute error
# y2 = np.array([1.093117971,
# 1.614285544,
# 0.979343551,
# 1.26806264])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$|\mathbf{D}|$', fontsize=24, fontweight="bold")
ax1.set_xticks(x)
ax1.set_xticklabels(x, fontsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(x, y1, marker='o', color=color1, linewidth=3, markersize=14, label='RE')
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(0, 5)  # Set Y-axis range for Relative Error

# Create secondary y-axis
# ax2 = ax1.twinx()
# color2 = 'black'
# ax2.set_ylabel(r'AE', color=color2, fontsize=24, fontweight="bold")
# ax2.plot(x, y2, marker='X', color=color2, linewidth=3, markersize=12, linestyle='--',label='AE')
# ax2.tick_params(axis='y', labelcolor=color2, labelsize=18, rotation=45)
# ax2.set_ylim(0.5,2)  # Set Y-axis range for Absolute Error

# Adjust layout and save
# ax1.legend(fontsize=18, loc='lower left')
# ax2.legend(fontsize=18, loc='lower right')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/scalability/avg_Jackson_scalability_re.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
x = [2500, 5000, 7500, 10000]  

# time
y1 = np.array([0.28137931,
0.309310345,
0.270689655,
0.28])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$|\mathbf{D}|$', fontsize=24, fontweight="bold")
ax1.set_xticks(x)
ax1.set_xticklabels(x, fontsize=18)
ax1.set_ylabel(r'Time (sec)', color=color1, fontsize=24, fontweight="bold")
ax1.plot(x, y1, marker='o', color=color1, linewidth=3, markersize=14)
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(0, 0.5)  # Set Y-axis range for Relative Error

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/scalability/avg_Jackson_scalability.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# PCT eICU scalability
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
x = [2500, 5000, 7500, 10000]  

# relative error
y1 = np.array([3.30,
3.794663048,
3.657718121,
3.397027601])
# absolute error
# y2 = np.array([9.633333333,
# 11.18666667,
# 10.9,
# 10.13333333])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$|\mathbf{D}|$', fontsize=24, fontweight="bold")
ax1.set_xticks(x)
ax1.set_xticklabels(x, fontsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(x, y1, marker='o', color=color1, linewidth=3, markersize=14, label='RE')
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(0, 5)  # Set Y-axis range for Relative Error

# Create secondary y-axis
# ax2 = ax1.twinx()
# color2 = 'black'
# ax2.set_ylabel('AE (1e-3)', color=color2, fontsize=24, fontweight="bold")
# ax2.plot(x, y2, marker='X', color=color2, linewidth=3, markersize=12, linestyle='--',label='AE')
# ax2.tick_params(axis='y', labelcolor=color2, labelsize=18, rotation=45)
# ax2.set_ylim(8, 12)  # Set Y-axis range for Absolute Error

# Adjust layout and save
# ax1.legend(fontsize=18, loc='center left')
# ax2.legend(fontsize=18, loc='center right')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/scalability/pct_Jackson_scalability_re.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
x = [2500, 5000, 7500, 10000]  

# time
y1 = np.array([0.15,
0.135862069,
0.138275862,
0.147241379])

# Create the plot
fig, ax1 = plt.subplots(figsize=(8, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$|\mathbf{D}|$', fontsize=24, fontweight="bold")
ax1.set_xticks(x)
ax1.set_xticklabels(x, fontsize=18)
ax1.set_ylabel(r'Time (sec)', color=color1, fontsize=24, fontweight="bold")
ax1.plot(x, y1, marker='o', color=color1, linewidth=3, markersize=14)
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(0, 0.5)  # Set Y-axis range for Relative Error

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/scalability/pct_Jackson_scalability.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # hypothesis testing

# %%
# non-PQA AVG
import matplotlib.pyplot as plt
import numpy as np

eICU = [0.95515873, 0.950238095, 0.843412698, 0.758492063, 0.759920635]
mimic = [0.956984127, 0.957936508, 0.940873016, 0.904603175, 0.915238095]
amazon_e = [0.847857143, 0.83531746, 0.521666667, 0.54984127, 0.508174603]
amazon_hh = [0.810714286, 0.785873016, 0.54952381, 0.559126984, 0.514761905]
jackson = [0.974444444, 0.966825397, 0.848253968, 0.77547619, 0.767539683]
methods = ['SPRinT-V', 'PQE-PT','PQE-RT','SUPG-PT', 'SUPG-RT']

# Hatching patterns for each dataset
hatches = ['XX', '*', '||', '--', '..']

data = [eICU, mimic, amazon_e, amazon_hh, jackson]
datasets = [r'$\mathbf{eICU}$', r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 4))
bar_width = 0.15  # Reduced bar width for more spacing
spacing = 0.03  # Extra spacing between groups
x = np.arange(len(methods))

# Plot bars for each dataset with hatching patterns
for i, (acc, hatch, label) in enumerate(zip(data, hatches, datasets)):
    ax.bar(
        x + i * (bar_width + spacing),
        acc,
        bar_width,
        color='white',  # All bars are white to highlight hatching
        edgecolor='black',  # Black border for better visibility
        hatch=hatch,
        label=label
    )

# Customize the plot
ax.set_ylabel('Accuracy', fontsize=24, fontweight='bold')
ax.set_xticks(x + (bar_width + spacing) * (len(data) - 1) / 2)
ax.set_xticklabels(methods, fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=18, rotation=45)
ax.tick_params(axis='x', labelsize=18)

# Add legend
ax.legend(fontsize=18, loc='lower left')

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/HT/HT_PQE_AVG.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# non-PQA PCT
import matplotlib.pyplot as plt
import numpy as np

eICU = [0.91515873, 0.801587302, 0.598492063, 0.774761905, 0.614365079]
mimic = [0.93547619, 0.619126984, 0.719365079, 0.5, 0.585714286]
amazon_e = [0.787142857, 0.770952381, 0.526349206, 0.797698413, 0.571904762]
amazon_hh = [0.765714286, 0.717539683, 0.56031746, 0.798174603, 0.576349206]
jackson = [0.942063492, 0.932460317, 0.5, 0.728412698, 0.501269841]
methods = ['SPRinT-C', 'PQE-PT','PQE-RT','SUPG-PT', 'SUPG-RT']

# Hatching patterns for each dataset
hatches = ['XX', '*', '||', '--', '..']

data = [eICU, mimic, amazon_e, amazon_hh, jackson]
datasets = [r'$\mathbf{eICU}$', r'$\mathbf{MIMIC-III}$', r'$\mathbf{Amazon-E}$', r'$\mathbf{Amazon-HH}$', r'$\mathbf{Jackson}$']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 4))
bar_width = 0.15  # Reduced bar width for more spacing
spacing = 0.03  # Extra spacing between groups
x = np.arange(len(methods))

# Plot bars for each dataset with hatching patterns
for i, (acc, hatch, label) in enumerate(zip(data, hatches, datasets)):
    ax.bar(
        x + i * (bar_width + spacing),
        acc,
        bar_width,
        color='white',  # All bars are white to highlight hatching
        edgecolor='black',  # Black border for better visibility
        hatch=hatch,
        label=label
    )

# Customize the plot
ax.set_ylabel('Accuracy', fontsize=24, fontweight='bold')
ax.set_xticks(x + (bar_width + spacing) * (len(data) - 1) / 2)
ax.set_xticklabels(methods, fontsize=14, fontweight='bold')
ax.tick_params(axis='y', labelsize=18, rotation=45)
ax.tick_params(axis='x', labelsize=18)

# Add legend
ax.legend(fontsize=18, loc='lower left')

# Adjust layout and save
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/HT/HT_PQE_PCT.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # beta impact

# %%
# SUM mimic
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [2, 1.9, 1.8, 1.7, 1.6, 1.5, 1.4, 1.3, 1.2, 1.1, 1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]
# relative error
RE_sum = np.array([23.41875677,
23.43482374,
23.34957043,
23.30825537,
23.30825537,
22.98462069,
22.76886424,
22.41637459,
22.14110477,
21.93830026,
21.61548533,
20.71655476,
19.53612432,
16.92542749,
15.44192142,
14.3453124,
13.46967316,
15.31411754,
18.9600954,
27.99637768])

# Create the plot
fig, ax1 = plt.subplots(figsize=(4, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$\beta$', fontsize=24, fontweight="bold")
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE_sum, marker='o', color=color1, linewidth=3, markersize=12, label='RE')
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(10, 30)  # Set Y-axis range for Relative Error

# ax1.legend(fontsize=18, loc='upper left')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/beta/beta_impact_sum_mimic.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# AVG mimic
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [2, 1.9, 1.8, 1.7, 1.6, 1.5, 1.4, 1.3, 1.2, 1.1, 1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]
# relative error
RE_sum_mimic = np.array([5.170871325,
5.166988751,
5.173474148,
5.174242796,
5.174242796,
5.144782097,
5.137904844,
5.124977278,
5.197134875,
5.168851336,
5.153071319,
5.066858458,
5.053489987,
4.881197448,
4.873670117,
4.665299758,
4.329195519,
4.083992495,
4.223360209,
4.165661444])

# RE_sum_jackson = np.array([12.50747362,
# 11.82356246,
# 11.20335259,
# 9.158139722,
# 8.205730107,
# 6.828879258,
# 6.696561133,
# 5.791400827,
# 5.246127764,
# 4.865675535,
# 4.617591589,
# 4.501424501,
# 4.22108864,
# 4.836483287,
# 5.042584567,
# 4.849273705,
# 6.11883552,
# 8.194895871,
# 10.87998074,
# 13.95705429])
# Create the plot
fig, ax1 = plt.subplots(figsize=(4, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$\beta$', fontsize=24, fontweight="bold")
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE_sum_mimic, marker='o', color=color1, linewidth=3, markersize=12, label='MIMIC-III')
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(3.5, 5.5)  # Set Y-axis range for Relative Error

# ax1.legend(fontsize=18, loc='upper left')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/beta/beta_impact_avg_mimic.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# VAR mimic
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [2, 1.9, 1.8, 1.7, 1.6, 1.5, 1.4, 1.3, 1.2, 1.1, 1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]
# relative error
RE_sum = np.array([4.708291883,
4.716297113,
4.681646045,
4.692375415,
4.692375415,
4.68168366,
4.640021453,
4.644263263,
4.68403307,
4.702841681,
4.709974975,
4.808292736,
5.128191229,
4.969690794,
5.121960865,
5.195469345,
5.014094104,
4.934105369,
5.433649952,
7.266609526])

# Create the plot
fig, ax1 = plt.subplots(figsize=(4, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$\beta$', fontsize=24, fontweight="bold")
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE_sum, marker='o', color=color1, linewidth=3, markersize=12, label='RE')
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(4, 8)  # Set Y-axis range for Relative Error

# ax1.legend(fontsize=18, loc='upper left')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/beta/beta_impact_var_mimic.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # night-street

# %%
# SUM jackson
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [2, 1.9, 1.8, 1.7, 1.6, 1.5, 1.4, 1.3, 1.2, 1.1, 1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]
# relative error
RE_sum = np.array([12.50747362,
11.82356246,
11.20335259,
9.158139722,
8.205730107,
6.828879258,
6.696561133,
5.791400827,
5.246127764,
4.865675535,
4.617591589,
4.501424501,
4.22108864,
4.836483287,
5.042584567,
4.849273705,
6.11883552,
8.194895871,
10.87998074,
13.95705429])

# Create the plot
fig, ax1 = plt.subplots(figsize=(4, 4),constrained_layout=True)
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$\beta$', fontsize=24, fontweight="bold")
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE_sum, marker='o', color=color1, linewidth=3, markersize=12, label='RE')
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
# ax1.set_ylim(0, 15)  # Set Y-axis range for Relative Error

# ax1.legend(fontsize=18, loc='upper left')
# fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/beta/beta_impact_sum_jackson.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# AVG jackson
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [2, 1.9, 1.8, 1.7, 1.6, 1.5, 1.4, 1.3, 1.2, 1.1, 1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]
# relative error
RE_sum = np.array([3.81119639,
3.720082622,
3.59847832,
3.352129885,
3.168953554,
2.919955497,
2.774490415,
2.785384558,
2.623124586,
2.567644505,
2.483455488,
2.405027464,
2.2833456,
2.172392422,
2.096971967,
1.985476014,
1.825700394,
1.888525368,
1.949658402,
1.771654218])

# Create the plot
fig, ax1 = plt.subplots(figsize=(4, 4),constrained_layout=True)
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$\beta$', fontsize=24, fontweight="bold")
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE_sum, marker='o', color=color1, linewidth=3, markersize=12, label='RE')
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
ax1.set_ylim(1, 5)  # Set Y-axis range for Relative Error

# ax1.legend(fontsize=18, loc='upper left')
# fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/beta/beta_impact_avg_jackson.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# VAR jackson
import matplotlib.pyplot as plt
import numpy as np

# X-axis values (size of dataset D)
radius = [2, 1.9, 1.8, 1.7, 1.6, 1.5, 1.4, 1.3, 1.2, 1.1, 1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]
# relative error
RE_sum = np.array([5.414033708,
5.432136163,
5.489676354,
5.614169891,
5.53544555,
5.636272192,
5.702301248,
5.844703977,
5.80264515,
5.729372689,
5.713006244,
5.730056839,
5.949448371,
5.81665728,
5.845272092,
5.975136736,
5.702082612,
5.562978097,
5.853670726,
5.880757375])

# Create the plot
fig, ax1 = plt.subplots(figsize=(4, 4))
color1 = 'black'

# Plot on the primary y-axis
ax1.set_xlabel(r'$\beta$', fontsize=24, fontweight="bold")
ax1.tick_params(axis='x', labelcolor=color1, labelsize=18)
ax1.set_ylabel(r'RE', color=color1, fontsize=24, fontweight="bold")
ax1.plot(radius, RE_sum, marker='o', color=color1, linewidth=3, markersize=12, label='RE')
ax1.tick_params(axis='y', labelcolor=color1, labelsize=18, rotation=45)
# ax1.set_ylim(5.2, 6.1)  # Set Y-axis range for Relative Error

# ax1.legend(fontsize=18, loc='upper left')
fig.tight_layout()
plt.savefig('/Users/wangyun/Desktop/Graph_HT_2/final plots/beta/beta_impact_var_jackson.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
a="PQA-PT"
a[-2:]
# Out:
# 'PT'
